# %% [markdown]
# <a href="https://colab.research.google.com/github/hantswilliams/HHA-507-2022/blob/main/autoML/autoML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Pacakges

# %%
# !pip install tpot mljar-supervised
# Out:
# Requirement already satisfied: tpot in /opt/homebrew/lib/python3.10/site-packages (0.11.7)
# Collecting mljar-supervised
#   Using cached mljar_supervised-0.11.3-py3-none-any.whl
# Requirement already satisfied: numpy>=1.16.3 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.23.4)
# Requirement already satisfied: pandas>=0.24.2 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.5.1)
# Requirement already satisfied: xgboost>=1.1.0 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.6.2)
# Requirement already satisfied: stopit>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.1.2)
# Requirement already satisfied: deap>=1.2 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.3.3)
# Requirement already satisfied: joblib>=0.13.2 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.2.0)
# Requirement already satisfied: update-checker>=0.16 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (0.18.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.1.3)
# Requirement already satisfied: scipy>=1.3.1 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (1.8.1)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/homebrew/lib/python3.10/site-packages (from tpot) (4.64.1)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-3.3.3.tar.gz (1.5 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (3.4.1)
# Requirement already satisfied: shap>=0.36.0 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (0.41.0)
# Collecting catboost>=0.24.4
#   Downloading catboost-1.1.1-cp310-none-macosx_10_6_universal2.whl (22.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 18.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib>=3.2.2 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (3.6.0)
# Collecting category-encoders>=2.2.2
#   Using cached category_encoders-2.5.1.post0-py2.py3-none-any.whl (72 kB)
# Requirement already satisfied: seaborn>=0.11.1 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (0.12.1)
# Requirement already satisfied: scikit-plot==0.3.7 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (0.3.7)
# Collecting dtreeviz>=1.3.3
#   Using cached dtreeviz-1.4.0-py3-none-any.whl (72 kB)
# Requirement already satisfied: wordcloud>=1.8.1 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (1.8.2.2)
# Requirement already satisfied: tabulate>=0.8.7 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (0.9.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (4.4.0)
# Requirement already satisfied: optuna>=2.7.0 in /opt/homebrew/lib/python3.10/site-packages (from mljar-supervised) (3.0.3)
# Requirement already satisfied: graphviz in /opt/homebrew/lib/python3.10/site-packages (from catboost>=0.24.4->mljar-supervised) (0.20.1)
# Requirement already satisfied: plotly in /opt/homebrew/lib/python3.10/site-packages (from catboost>=0.24.4->mljar-supervised) (5.10.0)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.10/site-packages (from catboost>=0.24.4->mljar-supervised) (1.16.0)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/homebrew/lib/python3.10/site-packages (from category-encoders>=2.2.2->mljar-supervised) (0.13.2)
# Requirement already satisfied: patsy>=0.5.1 in /opt/homebrew/lib/python3.10/site-packages (from category-encoders>=2.2.2->mljar-supervised) (0.5.3)
# Requirement already satisfied: colour in /opt/homebrew/lib/python3.10/site-packages (from dtreeviz>=1.3.3->mljar-supervised) (0.1.5)
# Requirement already satisfied: pytest in /opt/homebrew/lib/python3.10/site-packages (from dtreeviz>=1.3.3->mljar-supervised) (7.2.0)
# Requirement already satisfied: wheel in /opt/homebrew/lib/python3.10/site-packages (from lightgbm>=3.0.0->mljar-supervised) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib>=3.2.2->mljar-supervised) (9.2.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (1.4.42)
# Requirement already satisfied: cliff in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (4.0.0)
# Requirement already satisfied: PyYAML in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (6.0)
# Requirement already satisfied: colorlog in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (6.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (1.8.1)
# Requirement already satisfied: cmaes>=0.8.2 in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (0.8.2)
# Requirement already satisfied: importlib-metadata<5.0.0 in /opt/homebrew/lib/python3.10/site-packages (from optuna>=2.7.0->mljar-supervised) (4.13.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=0.24.2->tpot) (2022.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=0.22.0->tpot) (3.1.0)
# Requirement already satisfied: cloudpickle in /opt/homebrew/lib/python3.10/site-packages (from shap>=0.36.0->mljar-supervised) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in /opt/homebrew/lib/python3.10/site-packages (from shap>=0.36.0->mljar-supervised) (0.0.7)
# Requirement already satisfied: numba in /opt/homebrew/lib/python3.10/site-packages (from shap>=0.36.0->mljar-supervised) (0.56.3)
# Requirement already satisfied: requests>=2.3.0 in /opt/homebrew/lib/python3.10/site-packages (from update-checker>=0.16->tpot) (2.28.1)
# Requirement already satisfied: Mako in /opt/homebrew/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=2.7.0->mljar-supervised) (1.2.3)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.10/site-packages (from importlib-metadata<5.0.0->optuna>=2.7.0->mljar-supervised) (3.10.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2022.9.24)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/homebrew/lib/python3.10/site-packages (from cliff->optuna>=2.7.0->mljar-supervised) (3.4.1)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/homebrew/lib/python3.10/site-packages (from cliff->optuna>=2.7.0->mljar-supervised) (4.1.0)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from cliff->optuna>=2.7.0->mljar-supervised) (2.4.2)
# Requirement already satisfied: autopage>=0.4.0 in /opt/homebrew/lib/python3.10/site-packages (from cliff->optuna>=2.7.0->mljar-supervised) (0.5.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /opt/homebrew/lib/python3.10/site-packages (from numba->shap>=0.36.0->mljar-supervised) (0.39.1)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.10/site-packages (from numba->shap>=0.36.0->mljar-supervised) (65.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/lib/python3.10/site-packages (from plotly->catboost>=0.24.4->mljar-supervised) (8.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/carolinesanicola/Library/Python/3.10/lib/python/site-packages (from pytest->dtreeviz>=1.3.3->mljar-supervised) (22.1.0)
# Requirement already satisfied: tomli>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from pytest->dtreeviz>=1.3.3->mljar-supervised) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/homebrew/lib/python3.10/site-packages (from pytest->dtreeviz>=1.3.3->mljar-supervised) (1.0.0)
# Requirement already satisfied: iniconfig in /opt/homebrew/lib/python3.10/site-packages (from pytest->dtreeviz>=1.3.3->mljar-supervised) (1.1.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/homebrew/lib/python3.10/site-packages (from pytest->dtreeviz>=1.3.3->mljar-supervised) (1.0.0rc9)
# Requirement already satisfied: wcwidth>=0.1.7 in /Users/carolinesanicola/Library/Python/3.10/lib/python/site-packages (from cmd2>=1.0.0->cliff->optuna>=2.7.0->mljar-supervised) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /opt/homebrew/lib/python3.10/site-packages (from cmd2>=1.0.0->cliff->optuna>=2.7.0->mljar-supervised) (1.8.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from stevedore>=2.0.1->cliff->optuna>=2.7.0->mljar-supervised) (5.11.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/homebrew/lib/python3.10/site-packages (from Mako->alembic>=1.5.0->optuna>=2.7.0->mljar-supervised) (2.1.1)
# Building wheels for collected packages: lightgbm
#   Building wheel for lightgbm (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [80 lines of output]
#       running bdist_wheel
#       /opt/homebrew/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/lightgbm
#       copying lightgbm/callback.py -> build/lib/lightgbm
#       copying lightgbm/compat.py -> build/lib/lightgbm
#       copying lightgbm/plotting.py -> build/lib/lightgbm
#       copying lightgbm/__init__.py -> build/lib/lightgbm
#       copying lightgbm/engine.py -> build/lib/lightgbm
#       copying lightgbm/dask.py -> build/lib/lightgbm
#       copying lightgbm/basic.py -> build/lib/lightgbm
#       copying lightgbm/libpath.py -> build/lib/lightgbm
#       copying lightgbm/sklearn.py -> build/lib/lightgbm
#       running egg_info
#       writing lightgbm.egg-info/PKG-INFO
#       writing dependency_links to lightgbm.egg-info/dependency_links.txt
#       writing requirements to lightgbm.egg-info/requires.txt
#       writing top-level names to lightgbm.egg-info/top_level.txt
#       reading manifest file 'lightgbm.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       no previously-included directories found matching 'build'
#       warning: no files found matching '*.so' under directory 'lightgbm'
#       warning: no files found matching '*.so' under directory 'compile'
#       warning: no files found matching '*.dll' under directory 'compile/Release'
#       warning: no files found matching '*.dll' under directory 'compile/windows/x64/DLL'
#       warning: no previously-included files matching '*.py[co]' found anywhere in distribution
#       warning: no previously-included files found matching 'compile/external_libs/compute/.git'
#       adding license file 'LICENSE'
#       writing manifest file 'lightgbm.egg-info/SOURCES.txt'
#       copying lightgbm/VERSION.txt -> build/lib/lightgbm
#       installing to build/bdist.macosx-13-arm64/wheel
#       running install
#       INFO:LightGBM:Starting to compile the library.
#       INFO:LightGBM:Starting to compile with CMake.
#       Traceback (most recent call last):
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 95, in silent_call
#           subprocess.check_call(cmd, stderr=log, stdout=log)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py", line 369, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', '/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/compile']' returned non-zero exit status 1.
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 334, in <module>
#           setup(name='lightgbm',
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 968, in run_commands
#           self.run_command(cmd)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "/opt/homebrew/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 335, in run
#           self.run_command('install')
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 319, in run_command
#           self.distribution.run_command(command)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 248, in run
#           compile_cpp(use_mingw=self.mingw, use_gpu=self.gpu, use_cuda=self.cuda, use_mpi=self.mpi,
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 198, in compile_cpp
#           silent_call(cmake_cmd, raise_error=True, error_msg='Please install CMake and all required dependencies first')
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 99, in silent_call
#           raise Exception("\n".join((error_msg, LOG_NOTICE)))
#       Exception: Please install CMake and all required dependencies first
#       The full version of error log was saved into /Users/carolinesanicola/LightGBM_compilation.log
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for lightgbm
#   Running setup.py clean for lightgbm
# Failed to build lightgbm
# Installing collected packages: lightgbm, dtreeviz, catboost, category-encoders, mljar-supervised
#   Running setup.py install for lightgbm ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for lightgbm did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       running install
#       /opt/homebrew/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       INFO:LightGBM:Starting to compile the library.
#       INFO:LightGBM:Starting to compile with CMake.
#       Traceback (most recent call last):
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 95, in silent_call
#           subprocess.check_call(cmd, stderr=log, stdout=log)
#         File "/opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py", line 369, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['cmake', '/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/compile']' returned non-zero exit status 1.
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 334, in <module>
#           setup(name='lightgbm',
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 968, in run_commands
#           self.run_command(cmd)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/dist.py", line 1217, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 987, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 248, in run
#           compile_cpp(use_mingw=self.mingw, use_gpu=self.gpu, use_cuda=self.cuda, use_mpi=self.mpi,
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 198, in compile_cpp
#           silent_call(cmake_cmd, raise_error=True, error_msg='Please install CMake and all required dependencies first')
#         File "/private/var/folders/jn/pt5km2k955l347vvjx4rm19c0000gn/T/pip-install-rbg0__3e/lightgbm_f662144f008545309d0608e39f3b318d/setup.py", line 99, in silent_call
#           raise Exception("\n".join((error_msg, LOG_NOTICE)))
#       Exception: Please install CMake and all required dependencies first
#       The full version of error log was saved into /Users/carolinesanicola/LightGBM_compilation.log
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> lightgbm
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from supervised.automl import AutoML
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 from sklearn.metrics import accuracy_score
#       2 from sklearn.model_selection import train_test_split
#       3 from supervised.automl import AutoML
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# # Options Available

# %% [markdown]
# - mode — the package ships with four built-in models.
#   - The Explain mode is ideal for explaining and understanding the data. It results in visualizations of feature importance as well as tree visualizations.
#   - The Perform is used when building ML models for production.
#   - The Compete is meant to build models used in machine learning competitions.
#   - The Optuna mode is used to search for highly-tuned ML models.
# - algorithms — specifies the algorithms you would like to use. They are usually passed in as a list.
# - results_path — the path where the results will be stored
# - total_time_limit — the total time in seconds for training the model
# - train_ensemble — dictates if an ensemble will be created at the end of the training process
# - stack_models — determines if a models stack will be created
# - eval_metric — the metric that will be optimized. If auto the logloss is used for classification problems while the rmse is used for regression problems

# %%
#automl = AutoML(
    # mode="Explain"
    # algorithms=""
    # results_path="AutoML_22",
    # total_time_limit=30 * 60,
    # train_ensemble=True,
    # stack_models="",
    # eval_metric=""
#)

# %% [markdown]
# # Healthcare Dataset - SPARCS

# %% [markdown]
# ## Load in dataset

# %%
import pandas as pd
sparcs = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA-507-2022/main/autoML/datasets/data_sparcs.csv')
sparcs
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 0              Western NY        Allegany                      226700.0
# 1              Western NY        Allegany                      228000.0
# 2              Western NY        Allegany                      228000.0
# 3              Western NY        Allegany                      228000.0
# 4              Western NY        Allegany                      228000.0
# ...                   ...             ...                           ...
# 23578         Long Island         Suffolk                     5157003.0
# 23579         Long Island         Suffolk                     5157003.0
# 23580         Long Island         Suffolk                     5157003.0
# 23581         Long Island         Suffolk                     5157003.0
# 23582         Long Island         Suffolk                     5157003.0
#
#        Facility Id                                      Facility Name  \
# 0             37.0                         Cuba Memorial Hospital Inc
# 1             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 2             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 4             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# ...            ...                                                ...
# 23578        943.0                     St Catherine of Siena Hospital
# 23579        943.0                     St Catherine of Siena Hospital
# 23580        943.0                     St Catherine of Siena Hospital
# 23581        943.0                     St Catherine of Siena Hospital
# 23582        943.0                     St Catherine of Siena Hospital
#
#          Age Group Zip Code - 3 digits Gender        Race          Ethnicity  \
# 0         30 to 49                 147      M       White  Not Span/Hispanic
# 1         18 to 29                 148      F       White  Not Span/Hispanic
# 2          0 to 17                 147      M       White  Not Span/Hispanic
# 3      70 or Older                 148      F       White  Not Span/Hispanic
# 4         50 to 69                 148      M       White  Not Span/Hispanic
# ...            ...                 ...    ...         ...                ...
# 23578  70 or Older                 117      F       White  Not Span/Hispanic
# 23579      0 to 17                 117      F  Other Race   Spanish/Hispanic
# 23580     30 to 49                 117      M       White  Not Span/Hispanic
# 23581  70 or Older                 117      M       White  Not Span/Hispanic
# 23582  70 or Older                 117      F       White  Not Span/Hispanic
#
#        ... APR Risk of Mortality APR Medical Surgical Description  \
# 0      ...                 Minor                          Medical
# 1      ...                 Minor                          Medical
# 2      ...                 Minor                          Medical
# 3      ...              Moderate                          Medical
# 4      ...                 Major                          Medical
# ...    ...                   ...                              ...
# 23578  ...              Moderate                          Medical
# 23579  ...                 Minor                          Medical
# 23580  ...                 Minor                          Medical
# 23581  ...                 Major                          Medical
# 23582  ...                 Major                          Medical
#
#              Payment Typology 1        Payment Typology 2  Payment Typology 3  \
# 0      Private Health Insurance                       NaN                 NaN
# 1        Blue Cross/Blue Shield                  Self-Pay            Self-Pay
# 2                      Self-Pay                  Self-Pay            Self-Pay
# 3                      Medicare                  Medicare            Self-Pay
# 4        Blue Cross/Blue Shield                  Medicare            Self-Pay
# ...                         ...                       ...                 ...
# 23578                  Medicare  Private Health Insurance                 NaN
# 23579  Private Health Insurance                       NaN                 NaN
# 23580                  Medicaid                       NaN                 NaN
# 23581                  Medicare                  Medicare                 NaN
# 23582                  Medicare  Private Health Insurance                 NaN
#
#       Birth Weight  Abortion Edit Indicator Emergency Department Indicator  \
# 0                0                        N                              Y
# 1                0                        N                              N
# 2             2900                        N                              N
# 3                0                        N                              Y
# 4                0                        N                              Y
# ...            ...                      ...                            ...
# 23578            0                        N                              Y
# 23579         3200                        N                              N
# 23580            0                        N                              N
# 23581            0                        N                              Y
# 23582            0                        N                              Y
#
#        Total Charges Total Costs
# 0            4757.01     4747.83
# 1            5090.25     2985.64
# 2            4948.50     2129.67
# 3            4719.75     8454.41
# 4           50384.75    34565.03
# ...              ...         ...
# 23578       50833.00     8961.40
# 23579       10948.00     2214.06
# 23580       46421.00    11083.24
# 23581       46122.00     7951.26
# 23582       32225.00     6212.95
#
# [23583 rows x 34 columns]

# %%
sparcs.columns
# Out:
# Index(['Health Service Area', 'Hospital County',
#        'Operating Certificate Number', 'Facility Id', 'Facility Name',
#        'Age Group', 'Zip Code - 3 digits', 'Gender', 'Race', 'Ethnicity',
#        'Length of Stay', 'Type of Admission', 'Patient Disposition',
#        'Discharge Year', 'CCS Diagnosis Code', 'CCS Diagnosis Description',
#        'CCS Procedure Code', 'CCS Procedure Description', 'APR DRG Code',
#        'APR DRG Description', 'APR MDC Code', 'APR MDC Description',
#        'APR Severity of Illness Code', 'APR Severity of Illness Description',
#        'APR Risk of Mortality', 'APR Medical Surgical Description',
#        'Payment Typology 1', 'Payment Typology 2', 'Payment Typology 3',
#        'Birth Weight', 'Abortion Edit Indicator',
#        'Emergency Department Indicator', 'Total Charges', 'Total Costs'],
#       dtype='object')

# %% [markdown]
# ## Potential variables of interest
#
# - APR Risk of Mortality (categorical)
# - Total costs (continuous)
# - Length of Stay

# %%
sparcs['Length of Stay'].describe()
# Out:
# count     23583
# unique       97
# top           2
# freq       5378
# Name: Length of Stay, dtype: object

# %%
sparcs['Total Costs'].describe()
# Out:
# count    2.358300e+04
# mean     1.472282e+04
# std      2.718098e+04
# min      6.700000e-01
# 25%      4.471700e+03
# 50%      8.320120e+03
# 75%      1.590874e+04
# max      1.591541e+06
# Name: Total Costs, dtype: float64

# %%
sparcs['APR Risk of Mortality'].value_counts()
# Out:
# Minor       13990
# Moderate     4952
# Major        3452
# Extreme      1187
# Name: APR Risk of Mortality, dtype: int64

# %% [markdown]
# ## Create some simplified binary versions

# %%
sparcs['Length of Stay'] = pd.to_numeric(sparcs['Length of Stay'], errors='coerce')
sparcs['sparcs_los'] = sparcs['Length of Stay'].apply(lambda x: 'long' if x > 3 else 'short')
sparcs.drop('Length of Stay', axis=1, inplace=True)
sparcs['sparcs_los'].value_counts()
# Out:
# short    13008
# long     10575
# Name: sparcs_los, dtype: int64

# %% [markdown]
# # MLJar Examples

# %% [markdown]
# ## Binary Classifier Example 1 - SPARCS

# %% [markdown]
# ### **Create new model**

# %%
X = sparcs.drop(columns=['sparcs_los'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 X = sparcs.drop(columns=['sparcs_los'])
#
# NameError: name 'sparcs' is not defined

# %%
y = sparcs["sparcs_los"]

# %%
X
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 0              Western NY        Allegany                      226700.0
# 1              Western NY        Allegany                      228000.0
# 2              Western NY        Allegany                      228000.0
# 3              Western NY        Allegany                      228000.0
# 4              Western NY        Allegany                      228000.0
# ...                   ...             ...                           ...
# 23578         Long Island         Suffolk                     5157003.0
# 23579         Long Island         Suffolk                     5157003.0
# 23580         Long Island         Suffolk                     5157003.0
# 23581         Long Island         Suffolk                     5157003.0
# 23582         Long Island         Suffolk                     5157003.0
#
#        Facility Id                                      Facility Name  \
# 0             37.0                         Cuba Memorial Hospital Inc
# 1             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 2             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 4             39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# ...            ...                                                ...
# 23578        943.0                     St Catherine of Siena Hospital
# 23579        943.0                     St Catherine of Siena Hospital
# 23580        943.0                     St Catherine of Siena Hospital
# 23581        943.0                     St Catherine of Siena Hospital
# 23582        943.0                     St Catherine of Siena Hospital
#
#          Age Group Zip Code - 3 digits Gender        Race          Ethnicity  \
# 0         30 to 49                 147      M       White  Not Span/Hispanic
# 1         18 to 29                 148      F       White  Not Span/Hispanic
# 2          0 to 17                 147      M       White  Not Span/Hispanic
# 3      70 or Older                 148      F       White  Not Span/Hispanic
# 4         50 to 69                 148      M       White  Not Span/Hispanic
# ...            ...                 ...    ...         ...                ...
# 23578  70 or Older                 117      F       White  Not Span/Hispanic
# 23579      0 to 17                 117      F  Other Race   Spanish/Hispanic
# 23580     30 to 49                 117      M       White  Not Span/Hispanic
# 23581  70 or Older                 117      M       White  Not Span/Hispanic
# 23582  70 or Older                 117      F       White  Not Span/Hispanic
#
#        ... APR Risk of Mortality APR Medical Surgical Description  \
# 0      ...                 Minor                          Medical
# 1      ...                 Minor                          Medical
# 2      ...                 Minor                          Medical
# 3      ...              Moderate                          Medical
# 4      ...                 Major                          Medical
# ...    ...                   ...                              ...
# 23578  ...              Moderate                          Medical
# 23579  ...                 Minor                          Medical
# 23580  ...                 Minor                          Medical
# 23581  ...                 Major                          Medical
# 23582  ...                 Major                          Medical
#
#              Payment Typology 1        Payment Typology 2 Payment Typology 3  \
# 0      Private Health Insurance                       NaN                NaN
# 1        Blue Cross/Blue Shield                  Self-Pay           Self-Pay
# 2                      Self-Pay                  Self-Pay           Self-Pay
# 3                      Medicare                  Medicare           Self-Pay
# 4        Blue Cross/Blue Shield                  Medicare           Self-Pay
# ...                         ...                       ...                ...
# 23578                  Medicare  Private Health Insurance                NaN
# 23579  Private Health Insurance                       NaN                NaN
# 23580                  Medicaid                       NaN                NaN
# 23581                  Medicare                  Medicare                NaN
# 23582                  Medicare  Private Health Insurance                NaN
#
#        Birth Weight Abortion Edit Indicator  Emergency Department Indicator  \
# 0                 0                       N                               Y
# 1                 0                       N                               N
# 2              2900                       N                               N
# 3                 0                       N                               Y
# 4                 0                       N                               Y
# ...             ...                     ...                             ...
# 23578             0                       N                               Y
# 23579          3200                       N                               N
# 23580             0                       N                               N
# 23581             0                       N                               Y
# 23582             0                       N                               Y
#
#       Total Charges  Total Costs
# 0           4757.01      4747.83
# 1           5090.25      2985.64
# 2           4948.50      2129.67
# 3           4719.75      8454.41
# 4          50384.75     34565.03
# ...             ...          ...
# 23578      50833.00      8961.40
# 23579      10948.00      2214.06
# 23580      46421.00     11083.24
# 23581      46122.00      7951.26
# 23582      32225.00      6212.95
#
# [23583 rows x 33 columns]

# %%
y
# Out:
# 0        short
# 1        short
# 2        short
# 3        short
# 4         long
#          ...
# 23578     long
# 23579    short
# 23580     long
# 23581     long
# 23582     long
# Name: sparcs_los, Length: 23583, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.25)
#
# NameError: name 'train_test_split' is not defined

# %%
X_test
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 18664       New York City          Queens                     7003004.0
# 6994        Hudson Valley        Dutchess                     1302001.0
# 18784       New York City          Queens                     7003007.0
# 17631       New York City       Manhattan                     7002054.0
# 11362       New York City           Kings                     7001003.0
# ...                   ...             ...                           ...
# 129            Western NY      Chautauqua                      602001.0
# 21182         Long Island          Nassau                     2950001.0
# 5579      Capital/Adirond          Albany                      101004.0
# 21325         Long Island          Nassau                     2950001.0
# 13414       New York City           Kings                     7001037.0
#
#        Facility Id                                    Facility Name  \
# 18664       1630.0                Long Island Jewish Medical Center
# 6994         181.0                   Vassar Brothers Medical Center
# 18784       1633.0                           Queens Hospital Center
# 17631       3975.0  New York Presbyterian Hospital - Allen Hospital
# 11362       1288.0       Brooklyn Hospital Center - Downtown Campus
# ...            ...                                              ...
# 129          103.0                    Woman's Christian Association
# 21182        527.0                South Nassau Communities Hospital
# 5579           5.0                               St Peters Hospital
# 21325        527.0                South Nassau Communities Hospital
# 13414       1320.0                  University Hospital of Brooklyn
#
#          Age Group Zip Code - 3 digits Gender                    Race  \
# 18664     18 to 29                 113      M              Other Race
# 6994   70 or Older                 126      F                   White
# 18784  70 or Older                 114      F                   White
# 17631     30 to 49                 OOS      F  Black/African American
# 11362     50 to 69                 114      F  Black/African American
# ...            ...                 ...    ...                     ...
# 129    70 or Older                 147      F                   White
# 21182  70 or Older                 115      M                   White
# 5579   70 or Older                 123      F                   White
# 21325  70 or Older                 115      F                   White
# 13414     50 to 69                 112      M  Black/African American
#
#                Ethnicity  ... APR Risk of Mortality  \
# 18664   Spanish/Hispanic  ...                 Minor
# 6994   Not Span/Hispanic  ...              Moderate
# 18784            Unknown  ...                 Minor
# 17631  Not Span/Hispanic  ...                 Minor
# 11362            Unknown  ...              Moderate
# ...                  ...  ...                   ...
# 129    Not Span/Hispanic  ...              Moderate
# 21182   Spanish/Hispanic  ...              Moderate
# 5579   Not Span/Hispanic  ...              Moderate
# 21325  Not Span/Hispanic  ...              Moderate
# 13414  Not Span/Hispanic  ...              Moderate
#
#       APR Medical Surgical Description      Payment Typology 1  \
# 18664                          Medical                Medicaid
# 6994                           Medical                Medicare
# 18784                          Medical                Medicare
# 17631                          Medical                Medicaid
# 11362                         Surgical  Blue Cross/Blue Shield
# ...                                ...                     ...
# 129                            Medical                Medicare
# 21182                          Medical                Medicare
# 5579                           Medical                Medicare
# 21325                          Medical                Medicare
# 13414                          Medical                Medicaid
#
#              Payment Typology 2        Payment Typology 3  Birth Weight  \
# 18664                  Medicaid                  Self-Pay             0
# 6994                        NaN                       NaN             0
# 18784                  Medicare  Private Health Insurance             0
# 17631                  Self-Pay                       NaN             0
# 11362                  Self-Pay                       NaN             0
# ...                         ...                       ...           ...
# 129                    Medicare                       NaN             0
# 21182                  Medicare                       NaN             0
# 5579   Private Health Insurance                       NaN             0
# 21325                  Medicare                       NaN             0
# 13414                  Self-Pay                       NaN             0
#
#       Abortion Edit Indicator  Emergency Department Indicator Total Charges  \
# 18664                       N                               Y      36909.00
# 6994                        N                               Y      33749.32
# 18784                       N                               N      22400.00
# 17631                       N                               N     680561.47
# 11362                       N                               Y      55032.23
# ...                       ...                             ...           ...
# 129                         N                               Y       4825.80
# 21182                       N                               Y      56879.72
# 5579                        N                               Y      16730.69
# 21325                       N                               Y      51917.30
# 13414                       N                               N       6725.00
#
#        Total Costs
# 18664      7266.25
# 6994       8782.71
# 18784     11047.39
# 17631    161077.77
# 11362     13654.07
# ...            ...
# 129        2401.68
# 21182     10790.79
# 5579       3729.33
# 21325     11391.66
# 13414      4385.89
#
# [5896 rows x 33 columns]

# %%
automl = AutoML(results_path="sparcs_binary_los", mode="Explain")

# %%
automl.fit(X_train, y_train)
# Out:
# Linear algorithm was disabled.
# AutoML directory: sparcs_binary_los
# The task is binary_classification with evaluation metric logloss
# AutoML will use algorithms: ['Baseline', 'Decision Tree', 'Random Forest', 'Xgboost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'ensemble']
# * Step simple_algorithms will try to check up to 2 models
# 1_Baseline logloss 0.687821 trained in 0.58 seconds
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# 2_DecisionTree logloss 0.448005 trained in 15.09 seconds
# * Step default_algorithms will try to check up to 3 models
# 3_Default_Xgboost logloss 0.259742 trained in 20.64 seconds
# 4_Default_NeuralNetwork logloss 0.400019 trained in 7.95 seconds
# 5_Default_RandomForest logloss 0.391253 trained in 20.0 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble logloss 0.259742 trained in 1.13 seconds
# AutoML fit time: 75.1 seconds
# AutoML best model: 3_Default_Xgboost
# AutoML(results_path='sparcs_binary_los')

# %%
pred = automl.predict(X_test)
pred
# Out:
# array(['long', 'long', 'long', ..., 'short', 'long', 'short'],
#       dtype=object)

# %%
automl.report()

# %% [markdown]
# ### **Test new (not really) data**

# %%
# load in the data model 

automl_sparcs_los = AutoML(results_path="sparcs_binary_los")

# %%
# create a new dataset that follows the same data structure as the training set
X_withlos = sparcs.sample(25)
X_withoutlos = X_withlos.drop(columns=['sparcs_los'])

# %%
X_withlos
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 15552       New York City       Manhattan                     7002024.0
# 6324      Capital/Adirond      Rensselaer                     4102002.0
# 14296       New York City       Manhattan                     7002002.0
# 13714       New York City       Manhattan                     7002054.0
# 4629           Central NY        Onondaga                     3301007.0
#
#        Facility Id                                   Facility Name Age Group  \
# 15552       1456.0                            Mount Sinai Hospital  30 to 49
# 6324         756.0                              Samaritan Hospital  50 to 69
# 14296       1439.0                         Mount Sinai Beth Israel  50 to 69
# 13714       1437.0  New York-Presbyterian/Lower Manhattan Hospital  30 to 49
# 4629         635.0  University Hospital SUNY Health Science Center  50 to 69
#
#       Zip Code - 3 digits Gender                    Race          Ethnicity  \
# 15552                 113      F                   White  Not Span/Hispanic
# 6324                  125      M                   White  Not Span/Hispanic
# 14296                 100      M  Black/African American   Spanish/Hispanic
# 13714                 112      M                   White  Not Span/Hispanic
# 4629                  130      M              Other Race  Not Span/Hispanic
#
#        ... APR Medical Surgical Description        Payment Typology 1  \
# 15552  ...                         Surgical  Private Health Insurance
# 6324   ...                         Surgical  Private Health Insurance
# 14296  ...                         Surgical                  Medicaid
# 13714  ...                         Surgical  Private Health Insurance
# 4629   ...                         Surgical  Private Health Insurance
#
#        Payment Typology 2  Payment Typology 3 Birth Weight  \
# 15552            Self-Pay                 NaN            0
# 6324             Self-Pay            Self-Pay            0
# 14296            Medicaid            Self-Pay            0
# 13714            Self-Pay                 NaN            0
# 4629                  NaN                 NaN            0
#
#        Abortion Edit Indicator Emergency Department Indicator  Total Charges  \
# 15552                        N                              N       36155.14
# 6324                         N                              Y      113306.08
# 14296                        N                              Y       78430.10
# 13714                        N                              Y       18995.85
# 4629                         N                              N      124879.40
#
#       Total Costs  sparcs_los
# 15552    14532.50        long
# 6324     44874.17        long
# 14296    19496.22        long
# 13714     5751.28       short
# 4629     56514.75        long
#
# [5 rows x 34 columns]

# %%
X_withoutlos
# Out:
#       Health Service Area Hospital County  Operating Certificate Number  \
# 15552       New York City       Manhattan                     7002024.0
# 6324      Capital/Adirond      Rensselaer                     4102002.0
# 14296       New York City       Manhattan                     7002002.0
# 13714       New York City       Manhattan                     7002054.0
# 4629           Central NY        Onondaga                     3301007.0
#
#        Facility Id                                   Facility Name Age Group  \
# 15552       1456.0                            Mount Sinai Hospital  30 to 49
# 6324         756.0                              Samaritan Hospital  50 to 69
# 14296       1439.0                         Mount Sinai Beth Israel  50 to 69
# 13714       1437.0  New York-Presbyterian/Lower Manhattan Hospital  30 to 49
# 4629         635.0  University Hospital SUNY Health Science Center  50 to 69
#
#       Zip Code - 3 digits Gender                    Race          Ethnicity  \
# 15552                 113      F                   White  Not Span/Hispanic
# 6324                  125      M                   White  Not Span/Hispanic
# 14296                 100      M  Black/African American   Spanish/Hispanic
# 13714                 112      M                   White  Not Span/Hispanic
# 4629                  130      M              Other Race  Not Span/Hispanic
#
#        ... APR Risk of Mortality APR Medical Surgical Description  \
# 15552  ...                 Minor                         Surgical
# 6324   ...              Moderate                         Surgical
# 14296  ...              Moderate                         Surgical
# 13714  ...                 Minor                         Surgical
# 4629   ...                 Minor                         Surgical
#
#              Payment Typology 1  Payment Typology 2 Payment Typology 3  \
# 15552  Private Health Insurance            Self-Pay                NaN
# 6324   Private Health Insurance            Self-Pay           Self-Pay
# 14296                  Medicaid            Medicaid           Self-Pay
# 13714  Private Health Insurance            Self-Pay                NaN
# 4629   Private Health Insurance                 NaN                NaN
#
#        Birth Weight Abortion Edit Indicator  Emergency Department Indicator  \
# 15552             0                       N                               N
# 6324              0                       N                               Y
# 14296             0                       N                               Y
# 13714             0                       N                               Y
# 4629              0                       N                               N
#
#       Total Charges  Total Costs
# 15552      36155.14     14532.50
# 6324      113306.08     44874.17
# 14296      78430.10     19496.22
# 13714      18995.85      5751.28
# 4629      124879.40     56514.75
#
# [5 rows x 33 columns]

# %%
predict = automl.predict(X_withoutlos)
predict
# Out:
# array(['short', 'short', 'long', 'short', 'short', 'short', 'short',
#        'long', 'long', 'short', 'short', 'long', 'short', 'short',
#        'short', 'short', 'long', 'short', 'short', 'long', 'short',
#        'long', 'short', 'short', 'long'], dtype=object)

# %%
# actual values from X_withlos
values_actual = X_withlos['sparcs_los'].values.tolist()
values_predicted = predict.tolist()
output = pd.DataFrame({'actual': values_actual, 'predicted': values_predicted})
output
# Out:
#    actual predicted
# 0   short     short
# 1   short     short
# 2    long      long
# 3   short     short
# 4   short     short
# 5   short     short
# 6   short     short
# 7    long      long
# 8    long      long
# 9   short     short
# 10  short     short
# 11  short      long
# 12  short     short
# 13  short     short
# 14  short     short
# 15  short     short
# 16  short      long
# 17  short     short
# 18  short     short
# 19   long      long
# 20  short     short
# 21   long      long
# 22  short     short
# 23  short     short
# 24   long      long

# %% [markdown]
# ## Binary Classifier Example 2 - GENERIC

# %%
import pandas as pd
from supervised.automl import AutoML
import os

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

df = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/HHA-507-2022/main/autoML/datasets/data_binary_bank.csv")

X = df[df.columns[:-1]]
y = df["y"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [7], line 2
#       1 import pandas as pd
# ----> 2 from supervised.automl import AutoML
#       3 import os
#       5 from sklearn.metrics import accuracy_score
#
# ModuleNotFoundError: No module named 'supervised'

# %%
X

# %%
y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.25)

# %%
automl = AutoML(
    # results_path="AutoML_22",
    # total_time_limit=30 * 60,
    # start_random_models=10,
    # hill_climbing_steps=3,
    # top_models_to_improve=3,
    # train_ensemble=True,
    mode="Explain"
)

automl.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 automl = AutoML(
#       2     # results_path="AutoML_22",
#       3     # total_time_limit=30 * 60,
#       4     # start_random_models=10,
#       5     # hill_climbing_steps=3,
#       6     # top_models_to_improve=3,
#       7     # train_ensemble=True,
#       8     mode="Explain"
#       9 )
#      11 automl.fit(X_train, y_train)
#
# NameError: name 'AutoML' is not defined

# %%
pred = automl.predict(X_test)
pred
# print("Test accuracy", accuracy_score(y_test, pred["label"]))

# %%
automl.report()

# %% [markdown]
# ## Regression - Example - GENERIC

# %% [markdown]
# ## Regression - Example 2 - GENERIC

# %%
import numpy as np
import pandas as pd
from supervised.automl import AutoML

df = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/HHA-507-2022/main/autoML/datasets/data_regression_housing.csv")
x_cols = [c for c in df.columns if c != "MEDV"]
X = df[x_cols]
y = df["MEDV"]

# %%
df

# %%
x_cols

# %%
X

# %%
y

# %%
automl = AutoML()
automl.fit(X, y)

# %%
df["predictions"] = automl.predict(X)

# %%
print("Predictions")
print(df[["MEDV", "predictions"]].head())

# %% [markdown]
# ## Multiclass Classifier - GENERIC

# %%
import pandas as pd
import numpy as np
from supervised.automl import AutoML
import supervised


import warnings

from sklearn import datasets
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA

from supervised import AutoML
from supervised.exceptions import AutoMLException

# warnings.filterwarnings('error')
warnings.filterwarnings(
    "error", category=pd.core.common.SettingWithCopyWarning
)  # message="*ndarray*")

df = pd.read_csv("https://raw.githubusercontent.com/hantswilliams/HHA-507-2022/main/autoML/datasets/data_classes_iris.csv")
X = df[["feature_1", "feature_2", "feature_3", "feature_4"]]
y = df["class"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from supervised.automl import AutoML
#       4 import supervised
#       7 import warnings
#
# ModuleNotFoundError: No module named 'supervised'

# %%
df

# %%
X

# %%
y.value_counts()

# %%
automl = AutoML()

# %%
automl.fit(X, y)

# %%
predictions = automl.predict_all(X)

# %%
print(predictions.head())
print(predictions.tail())

print(X.shape)
print(predictions.shape)

# %% [markdown]
# # Download outputs

# %%
# get current working directory
import os
os.getcwd()
# Out:
# '/content'

# %%
folders = os.listdir()
foldersML = [x for x in folders if x.startswith('sparcs')]
print(foldersML)

# %%
# !zip -r /content/sparcs_binary_los.zip /content/sparcs_binary_los
# Out:
#   adding: content/sparcs_binary_los/ (stored 0%)
#   adding: content/sparcs_binary_los/Ensemble/ (stored 0%)
#   adding: content/sparcs_binary_los/Ensemble/roc_curve.png (deflated 9%)
#   adding: content/sparcs_binary_los/Ensemble/precision_recall_curve.png (deflated 11%)
#   adding: content/sparcs_binary_los/Ensemble/predictions_ensemble.csv (deflated 62%)
#   adding: content/sparcs_binary_los/Ensemble/lift_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/Ensemble/confusion_matrix_normalized.png (deflated 18%)
#   adding: content/sparcs_binary_los/Ensemble/calibration_curve_curve.png (deflated 14%)
#   adding: content/sparcs_binary_los/Ensemble/cumulative_gains_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/Ensemble/learning_curves.png (deflated 11%)
#   adding: content/sparcs_binary_los/Ensemble/confusion_matrix.png (deflated 17%)
#   adding: content/sparcs_binary_los/Ensemble/README.md (deflated 67%)
#   adding: content/sparcs_binary_los/Ensemble/ensemble.json (deflated 44%)
#   adding: content/sparcs_binary_los/Ensemble/status.txt (stored 0%)
#   adding: content/sparcs_binary_los/Ensemble/ks_statistic.png (deflated 7%)
#   adding: content/sparcs_binary_los/correlation_heatmap.png (deflated 17%)
#   adding: content/sparcs_binary_los/ldb_performance_boxplot.png (deflated 23%)
#   adding: content/sparcs_binary_los/progress.json (deflated 92%)
#   adding: content/sparcs_binary_los/split_train_indices.npy (deflated 67%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/ (stored 0%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/roc_curve.png (deflated 8%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/precision_recall_curve.png (deflated 9%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_summary.png (deflated 15%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/lift_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0.random_forest (deflated 0%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/predictions_validation.csv (deflated 65%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/confusion_matrix_normalized.png (deflated 19%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_importance.csv (deflated 45%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/calibration_curve_curve.png (deflated 14%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/cumulative_gains_curve.png (deflated 6%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learning_curves.png (deflated 9%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/confusion_matrix.png (deflated 16%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/README.md (deflated 68%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_class_0_best_decisions.png (deflated 11%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_training.log (deflated 55%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/permutation_importance.png (deflated 15%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/shap_importance.png (deflated 15%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_class_1_worst_decisions.png (deflated 9%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_dependence.png (deflated 7%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/framework.json (deflated 80%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_class_1_best_decisions.png (deflated 11%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_importance.csv (deflated 47%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/status.txt (stored 0%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/learner_fold_0_shap_class_0_worst_decisions.png (deflated 10%)
#   adding: content/sparcs_binary_los/5_Default_RandomForest/ks_statistic.png (deflated 6%)
#   adding: content/sparcs_binary_los/1_Baseline/ (stored 0%)
#   adding: content/sparcs_binary_los/1_Baseline/roc_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/1_Baseline/precision_recall_curve.png (deflated 11%)
#   adding: content/sparcs_binary_los/1_Baseline/learner_fold_0.baseline (stored 0%)
#   adding: content/sparcs_binary_los/1_Baseline/lift_curve.png (deflated 12%)
#   adding: content/sparcs_binary_los/1_Baseline/predictions_validation.csv (deflated 98%)
#   adding: content/sparcs_binary_los/1_Baseline/confusion_matrix_normalized.png (deflated 20%)
#   adding: content/sparcs_binary_los/1_Baseline/calibration_curve_curve.png (deflated 13%)
#   adding: content/sparcs_binary_los/1_Baseline/cumulative_gains_curve.png (deflated 6%)
#   adding: content/sparcs_binary_los/1_Baseline/learning_curves.png (deflated 29%)
#   adding: content/sparcs_binary_los/1_Baseline/confusion_matrix.png (deflated 18%)
#   adding: content/sparcs_binary_los/1_Baseline/README.md (deflated 69%)
#   adding: content/sparcs_binary_los/1_Baseline/learner_fold_0_training.log (deflated 8%)
#   adding: content/sparcs_binary_los/1_Baseline/framework.json (deflated 72%)
#   adding: content/sparcs_binary_los/1_Baseline/status.txt (stored 0%)
#   adding: content/sparcs_binary_los/1_Baseline/ks_statistic.png (deflated 9%)
#   adding: content/sparcs_binary_los/README.md (deflated 68%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/ (stored 0%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/roc_curve.png (deflated 9%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/precision_recall_curve.png (deflated 12%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_summary.png (deflated 15%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/lift_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/predictions_validation.csv (deflated 63%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/confusion_matrix_normalized.png (deflated 18%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_importance.csv (deflated 46%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/calibration_curve_curve.png (deflated 14%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/cumulative_gains_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learning_curves.png (deflated 7%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/confusion_matrix.png (deflated 17%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/README.md (deflated 68%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_class_0_best_decisions.png (deflated 7%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0.xgboost (deflated 56%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_training.log (deflated 53%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/permutation_importance.png (deflated 16%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/shap_importance.png (deflated 14%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_class_1_worst_decisions.png (deflated 5%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_dependence.png (deflated 4%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/framework.json (deflated 80%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_class_1_best_decisions.png (deflated 6%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_importance.csv (deflated 46%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/status.txt (stored 0%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/learner_fold_0_shap_class_0_worst_decisions.png (deflated 5%)
#   adding: content/sparcs_binary_los/3_Default_Xgboost/ks_statistic.png (deflated 6%)
#   adding: content/sparcs_binary_los/data_info.json (deflated 84%)
#   adding: content/sparcs_binary_los/ldb_performance.png (deflated 26%)
#   adding: content/sparcs_binary_los/2_DecisionTree/ (stored 0%)
#   adding: content/sparcs_binary_los/2_DecisionTree/roc_curve.png (deflated 8%)
#   adding: content/sparcs_binary_los/2_DecisionTree/precision_recall_curve.png (deflated 11%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_summary.png (deflated 17%)
#   adding: content/sparcs_binary_los/2_DecisionTree/lift_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/2_DecisionTree/predictions_validation.csv (deflated 95%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_tree (deflated 87%)
#   adding: content/sparcs_binary_los/2_DecisionTree/confusion_matrix_normalized.png (deflated 19%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_importance.csv (deflated 50%)
#   adding: content/sparcs_binary_los/2_DecisionTree/calibration_curve_curve.png (deflated 14%)
#   adding: content/sparcs_binary_los/2_DecisionTree/cumulative_gains_curve.png (deflated 6%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learning_curves.png (deflated 31%)
#   adding: content/sparcs_binary_los/2_DecisionTree/confusion_matrix.png (deflated 17%)
#   adding: content/sparcs_binary_los/2_DecisionTree/README.md (deflated 72%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_class_0_best_decisions.png (deflated 14%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_training.log (deflated 7%)
#   adding: content/sparcs_binary_los/2_DecisionTree/permutation_importance.png (deflated 16%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0.decision_tree (stored 0%)
#   adding: content/sparcs_binary_los/2_DecisionTree/shap_importance.png (deflated 15%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_class_1_worst_decisions.png (deflated 14%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_dependence.png (deflated 8%)
#   adding: content/sparcs_binary_los/2_DecisionTree/framework.json (deflated 80%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_class_1_best_decisions.png (deflated 14%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_tree.svg (deflated 88%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_rules.txt (deflated 76%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_importance.csv (deflated 51%)
#   adding: content/sparcs_binary_los/2_DecisionTree/status.txt (stored 0%)
#   adding: content/sparcs_binary_los/2_DecisionTree/learner_fold_0_shap_class_0_worst_decisions.png (deflated 14%)
#   adding: content/sparcs_binary_los/2_DecisionTree/ks_statistic.png (deflated 7%)
#   adding: content/sparcs_binary_los/features_heatmap.png (deflated 13%)
#   adding: content/sparcs_binary_los/leaderboard.csv (deflated 42%)
#   adding: content/sparcs_binary_los/split_validation_indices.npy (deflated 66%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/ (stored 0%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/roc_curve.png (deflated 8%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/precision_recall_curve.png (deflated 11%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/lift_curve.png (deflated 7%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/predictions_validation.csv (deflated 58%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/confusion_matrix_normalized.png (deflated 18%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/calibration_curve_curve.png (deflated 14%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/learner_fold_0.neural_network (deflated 0%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/cumulative_gains_curve.png (deflated 6%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/learning_curves.png (deflated 8%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/confusion_matrix.png (deflated 17%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/README.md (deflated 65%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/learner_fold_0_training.log (deflated 53%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/permutation_importance.png (deflated 15%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/framework.json (deflated 80%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/learner_fold_0_importance.csv (deflated 45%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/status.txt (stored 0%)
#   adding: content/sparcs_binary_los/4_Default_NeuralNetwork/ks_statistic.png (deflated 6%)
#   adding: content/sparcs_binary_los/params.json (deflated 62%)
